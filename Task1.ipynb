# %% [markdown]
# <a href="https://colab.research.google.com/github/shydaparveen/-Generative-adversarial-network-GAN-/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as numpy

# %%
a= np.array([1,2,3,4,5])

# %%
dir(pd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3024108878.py in <cell line: 0>()
# ----> 1 dir(pd)
#
# NameError: name 'pd' is not defined

# %%
import numpy as np

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
a= np.array([1,2,3,4,5])

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (5,)

# %%
a.size
# Out:
# 5

# %%
a[0]
# Out:
# np.int64(1)

# %%
{
   "coord": {
      "lon": 7.367,
      "lat": 45.133
   },
   "weather": [
      {
         "id": 501,
         "main": "Rain",
         "description": "moderate rain",
         "icon": "10d"
      }
   ],
   "base": "stations",
   "main": {
      "temp": 284.2,
      "feels_like": 282.93,
      "temp_min": 283.06,
      "temp_max": 286.82,
      "pressure": 1021,
      "humidity": 60,
      "sea_level": 1021,
      "grnd_level": 910
   },
   "visibility": 10000,
   "wind": {
      "speed": 4.09,
      "deg": 121,
      "gust": 3.47
   },
   "rain": {
      "1h": 2.73
   },
   "clouds": {
      "all": 83
   },
   "dt": 1726660758,
   "sys": {
      "type": 1,
      "id": 6736,
      "country": "IT",
      "sunrise": 1726636384,
      "sunset": 1726680975
   },
   "timezone": 7200,
   "id": 3165523,
   "name": "Province of Turin",
   "cod": 200
}

# %%
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b[1,0]
# Out:
# np.int64(3)

# %%
a= np.matrix([[1,2,3],[10,20,30],[100,200,300]])

# %%
a
# Out:
# matrix([[  1,   2,   3],
#         [ 10,  20,  30],
#         [100, 200, 300]])

# %%
a[1:3,1:3]
# Out:
# matrix([[ 20,  30],
#         [200, 300]])

# %%
c=np.array([[1,2],[3,4]])

# %%
c
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
c[0:2,0:2]
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a= np.matrix([[1,2,3],[10,20,30],[100,200,300]])

# %%
a
# Out:
# matrix([[  1,   2,   3],
#         [ 10,  20,  30],
#         [100, 200, 300]])

# %%
a[1:3,1:3]
# Out:
# matrix([[ 20,  30],
#         [200, 300]])

# %%
a[0:2,0:2]
# Out:
# matrix([[ 1,  2],
#         [10, 20]])

# %%
a[0,:1]
# Out:
# matrix([[1]])

# %%
a[:,1]
# Out:
# matrix([[  2],
#         [ 20],
#         [200]])

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
x=pd.Series([1,2,3,4,5])

# %%
x
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
x.dtype
# Out:
# dtype('int64')

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x=pd.Series([1,2,3,4,5],index=["a","b","c","d","e"],name=" marks")

# %%
x
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name:  marks, dtype: int64

# %%
x.name
# Out:
# ' marks'

# %%
a
# Out:
# matrix([[  1,   2,   3],
#         [ 10,  20,  30],
#         [100, 200, 300]])

# %%
x.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d={"students":["a","b","c","d"],"math":[80,45,96,97],"science":[89,78,87,99]}

# %%
a
# Out:
# matrix([[  1,   2,   3],
#         [ 10,  20,  30],
#         [100, 200, 300]])

# %%
d
# Out:
# {'students': ['a', 'b', 'c', 'd'],
#  'math': [80, 45, 96, 97],
#  'science': [89, 78, 87, 99]}

# %%
d.keys()
# Out:
# dict_keys(['students', 'math', 'science'])

# %%
d.values()
# Out:
# dict_values([['a', 'b', 'c', 'd'], [80, 45, 96, 97], [89, 78, 87, 99]])

# %%
df=pd.DataFrame(d)
df
# Out:
#   students  math  science
# 0        a    80       89
# 1        b    45       78
# 2        c    96       87
# 3        d    97       99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   students  4 non-null      object
#  1   math      4 non-null      int64
#  2   science   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.students
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: students, dtype: object

# %%
df.math
# Out:
# 0    80
# 1    45
# 2    96
# 3    97
# Name: math, dtype: int64

# %%
dataGA=pd.read_csv("https://raw.githubusercontent.com/bapujik/dataSets/refs/heads/main/GAdata.csv")

# %%
dataGA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
import pandas as pd

# %%
dataGA1 = pd.read_csv("/content/GAdata.csv")

# %%
dataGA1.head(10)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
# 5           6        330          115                  5  4.5  3.0  9.34
# 6           7        321          109                  3  3.0  4.0  8.20
# 7           8        308          101                  2  3.0  4.0  7.90
# 8           9        302          102                  1  2.0  1.5  8.00
# 9          10        323          108                  3  3.5  3.0  8.60
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# ...

# %%
dataGA1.tail(10)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 490         491        307          105                  2  2.5  4.5  8.12
# 491         492        297           99                  4  3.0  3.5  7.81
# 492         493        298          101                  4  2.5  4.5  7.69
# 493         494        300           95                  2  3.0  1.5  8.22
# 494         495        301           99                  3  2.5  2.0  8.45
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 490         1             0.67
# 491         0             0.54
# 492         1             0.53
# ...

# %%
import pandas as pd

# %%
dataGA1 = pd.read_csv("/content/arrivals_2018.csv")

# %%
arrivals = pd.read_csv("/content/arrivals_2018.csv")

# %%
arrivals
# Out:
#     rank           city               country  arrivals_2017  arrivals_2018
# 0      1      Hong Kong             Hong Kong       27880300       29827200
# 1      2        Bangkok              Thailand       22453900       23688800
# 2      3         London               England       19827800       20715900
# 3      4      Singapore             Singapore       17618800       18551200
# 4      5          Macau                 Macau       17337200       18931400
# 5      6          Paris                France       15834200       16863500
# 6      7          Dubai  United Arab Emirates       15790000       16658500
# 7      8  New York City                   USA       13100000       13500000
# 8      9   Kuala Lumpur              Malaysia       12843500       13434000
# 9     10       Shenzhen                 China       12075100       12437300
# 10    11         Phuket              Thailand       11613100       11945500
# ...

# %%
dataGA1.plot()
# Out:
# <Axes: >

# %%
dataGA1.isnull()
# Out:
#      rank   city  country  arrivals_2017  arrivals_2018
# 0   False  False    False          False          False
# 1   False  False    False          False          False
# 2   False  False    False          False          False
# 3   False  False    False          False          False
# 4   False  False    False          False          False
# 5   False  False    False          False          False
# 6   False  False    False          False          False
# 7   False  False    False          False          False
# 8   False  False    False          False          False
# 9   False  False    False          False          False
# 10  False  False    False          False          False
# 11  False  False    False          False          False
# 12  False  False    False          False          False
# 13  False  False    False          False          False
# 14  False  False    False          False          False
# 15  False  False    False          False          False
# ...

# %%
dataGA1.isnull().sum()
# Out:
# rank             0
# city             0
# country          0
# arrivals_2017    0
# arrivals_2018    0
# dtype: int64

# %%
import pandas as pd

# %%
Bengaluru_House_Data=pd.read_csv("/content/Bengaluru_House_Data (1).csv")

# %%
import matplotlib.pyplot as plt

# %%
Bengaluru_House_Data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
Bengaluru_House_Data.bath
# Out:
# 0        2.0
# 1        5.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 13315    4.0
# 13316    5.0
# 13317    2.0
# 13318    4.0
# 13319    1.0
# Name: bath, Length: 13320, dtype: float64

# %%
plt.plot(Bengaluru_House_Data.bath,Bengaluru_House_Data.price)

# %%
plt.scatter([1,2,3,4],[10,20,30,40])

# %%
Bengaluru_House_Data.bath
# Out:
# 0        2.0
# 1        5.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 13315    4.0
# 13316    5.0
# 13317    2.0
# 13318    4.0
# 13319    1.0
# Name: bath, Length: 13320, dtype: float64

# %%
# !pip install openpyxl

# %%
import pandas as pd

# %%
df3=pd.read_excel("/content/edata.xlsx")

# %%
df3
# Out:
#           Name  Time  Marks
# 0       Bapuji    10     50
# 1     Appleton    15     60
# 2  Innovations    20     75
# 3     Machine     15     80
# 4     Learning    20     90

# %%
import pandas as pd

# %%
url1="https://api.exchangerate-api.com/v4/latest/USD"

# %%
url1
# Out:
# 'https://api.exchangerate-api.com/v4/latest/USD'

# %%
import pandas as pd

# %%
df4=pd.read_json(url1)

# %%
df4
# Out:
#                              provider  \
# USD  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# USD  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %%
import requests

# %%
url="https://www.worldcoinindex.com/"

# %%
data_url=requests.get(url)

# %%
print(data_url)
# Out:
# <Response [200]>

# %%
dir(data_url)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
print(data_url.text)
# Out:
# <!DOCTYPE html>
# <html style="background-color: #FFF">
# <head>
#
#     <meta http-equiv="Content-Type" content="text/html">
#     <meta name="mobile-web-app-capable" content="yes">
#     <meta charset="utf-8" />
#
#     <meta name="description" content="Cryptocoins ranked by 24hr trading volume, price info, charts, market cap and news" />
#         <meta name="keywords" content="Coin, index, worldcoin, coinindex, worldindex, cryptocoins, crypto, traded, exchanges, ranked, marketcap, coins, cryptocurrency ,coinprices, price, last trade time, trade, market cap, trading, traded, volume, rate, buy cryptocurrency, sell cryptocurrency" />
#     <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable = no">
#     <meta name="apple-mobile-web-app-capable" content="yes" />
#     <meta name="propeller" content="efad6eed15cdd45139ef34d287cc06ff" />
#
# ...

# %%
# !pip install lxml

# %%
html_data=pd.read_html(data_url.text)
# Out:
# /tmp/ipython-input-1055849547.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   html_data=pd.read_html(data_url.text)

# %%
print(html_data)
# Out:
# [       # Unnamed: 1         Name  Ticker  Last price       %     24 high  \
# 0      1        NaN     Ethereum     ETH  $ 4,427.18  +1.79%  $ 4,447.62
# 1      2        NaN      Bitcoin     BTC   $ 114,102  +0.10%   $ 114,482
# 2      3        NaN       Solana     SOL    $ 225.41  +0.61%    $ 225.61
# 3      4        NaN     Usd coin    USDC      $ 1.00  +0.02%      $ 1.00
# 4      5        NaN       Ripple     XRP      $ 3.02  +1.20%      $ 3.03
# ..   ...        ...          ...     ...         ...     ...         ...
# 97    96        NaN  Tether gold    XAUT  $ 3,618.28  -0.67%  $ 3,652.50
# 98    97        NaN        ai16z   AI16Z  $ 0.114646  +1.54%  $ 0.114802
# 99    98        NaN    Wayfinder  PROMPT  $ 0.182202  +0.15%  $ 0.186110
# 100   99        NaN    Trusta AI      TA  $ 0.120370  -7.48%  $ 0.134800
# 101  100        NaN        Syrup   SYRUP  $ 0.447990  +1.08%  $ 0.459305
#
#          24 low Price Charts 7d 24 volume  # Coins Market cap
# ...

# %%
type(html_data)
# Out:
# list

# %%
len(html_data)
# Out:
# 1

# %%
html_data[0]
# Out:
#        # Unnamed: 1         Name  Ticker  Last price       %     24 high  \
# 0      1        NaN     Ethereum     ETH  $ 4,427.18  +1.79%  $ 4,447.62
# 1      2        NaN      Bitcoin     BTC   $ 114,102  +0.10%   $ 114,482
# 2      3        NaN       Solana     SOL    $ 225.41  +0.61%    $ 225.61
# 3      4        NaN     Usd coin    USDC      $ 1.00  +0.02%      $ 1.00
# 4      5        NaN       Ripple     XRP      $ 3.02  +1.20%      $ 3.03
# ..   ...        ...          ...     ...         ...     ...         ...
# 97    96        NaN  Tether gold    XAUT  $ 3,618.28  -0.67%  $ 3,652.50
# 98    97        NaN        ai16z   AI16Z  $ 0.114646  +1.54%  $ 0.114802
# 99    98        NaN    Wayfinder  PROMPT  $ 0.182202  +0.15%  $ 0.186110
# 100   99        NaN    Trusta AI      TA  $ 0.120370  -7.48%  $ 0.134800
# 101  100        NaN        Syrup   SYRUP  $ 0.447990  +1.08%  $ 0.459305
#
#          24 low Price Charts 7d 24 volume  # Coins Market cap
# ...

# %%
dfhtml=html_data[0]

# %%
dfhtml
# Out:
#        # Unnamed: 1         Name  Ticker  Last price       %     24 high  \
# 0      1        NaN     Ethereum     ETH  $ 4,427.18  +1.79%  $ 4,447.62
# 1      2        NaN      Bitcoin     BTC   $ 114,102  +0.10%   $ 114,482
# 2      3        NaN       Solana     SOL    $ 225.41  +0.61%    $ 225.61
# 3      4        NaN     Usd coin    USDC      $ 1.00  +0.02%      $ 1.00
# 4      5        NaN       Ripple     XRP      $ 3.02  +1.20%      $ 3.03
# ..   ...        ...          ...     ...         ...     ...         ...
# 97    96        NaN  Tether gold    XAUT  $ 3,618.28  -0.67%  $ 3,652.50
# 98    97        NaN        ai16z   AI16Z  $ 0.114646  +1.54%  $ 0.114802
# 99    98        NaN    Wayfinder  PROMPT  $ 0.182202  +0.15%  $ 0.186110
# 100   99        NaN    Trusta AI      TA  $ 0.120370  -7.48%  $ 0.134800
# 101  100        NaN        Syrup   SYRUP  $ 0.447990  +1.08%  $ 0.459305
#
#          24 low Price Charts 7d 24 volume  # Coins Market cap
# ...

# %%
type(dfhtml)
# Out:
# pandas.core.frame.DataFrame

# %%
dfhtml.drop(columns=["#"],inplace=True)

# %%
dfhtml
# Out:
#     Unnamed: 1         Name  Ticker  Last price       %     24 high  \
# 0          NaN     Ethereum     ETH  $ 4,427.18  +1.79%  $ 4,447.62
# 1          NaN      Bitcoin     BTC   $ 114,102  +0.10%   $ 114,482
# 2          NaN       Solana     SOL    $ 225.41  +0.61%    $ 225.61
# 3          NaN     Usd coin    USDC      $ 1.00  +0.02%      $ 1.00
# 4          NaN       Ripple     XRP      $ 3.02  +1.20%      $ 3.03
# ..         ...          ...     ...         ...     ...         ...
# 97         NaN  Tether gold    XAUT  $ 3,618.28  -0.67%  $ 3,652.50
# 98         NaN        ai16z   AI16Z  $ 0.114646  +1.54%  $ 0.114802
# 99         NaN    Wayfinder  PROMPT  $ 0.182202  +0.15%  $ 0.186110
# 100        NaN    Trusta AI      TA  $ 0.120370  -7.48%  $ 0.134800
# 101        NaN        Syrup   SYRUP  $ 0.447990  +1.08%  $ 0.459305
#
#          24 low Price Charts 7d 24 volume  # Coins Market cap
# 0    $ 4,339.97             NaN  $ 15.84B  122.37M  $ 541.77B
# ...

# %%
dfhtml.drop(columns=["Unnamed: 1"],inplace=True)

# %%
dfhtml
# Out:
#             Name  Ticker  Last price       %     24 high      24 low  \
# 0       Ethereum     ETH  $ 4,427.18  +1.79%  $ 4,447.62  $ 4,339.97
# 1        Bitcoin     BTC   $ 114,102  +0.10%   $ 114,482   $ 113,732
# 2         Solana     SOL    $ 225.41  +0.61%    $ 225.61    $ 221.84
# 3       Usd coin    USDC      $ 1.00  +0.02%      $ 1.00  $ 0.999548
# 4         Ripple     XRP      $ 3.02  +1.20%      $ 3.03      $ 2.98
# ..           ...     ...         ...     ...         ...         ...
# 97   Tether gold    XAUT  $ 3,618.28  -0.67%  $ 3,652.50  $ 3,613.74
# 98         ai16z   AI16Z  $ 0.114646  +1.54%  $ 0.114802  $ 0.109043
# 99     Wayfinder  PROMPT  $ 0.182202  +0.15%  $ 0.186110  $ 0.178677
# 100    Trusta AI      TA  $ 0.120370  -7.48%  $ 0.134800  $ 0.115166
# 101        Syrup   SYRUP  $ 0.447990  +1.08%  $ 0.459305  $ 0.442616
#
#     Price Charts 7d 24 volume  # Coins Market cap
# 0               NaN  $ 15.84B  122.37M  $ 541.77B
# ...

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_by_number_of_military_and_paramilitary_personnel"

# %%
data_url=requests.get(url)

# %%
print(data_url)
# Out:
# <Response [403]>

# %%
url="https://www.iplt20.com/stats/2025"

# %%
url
# Out:
# 'https://www.iplt20.com/stats/2025'

# %%
print(data_url)
# Out:
# <Response [403]>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/arrivals_2018.csv")

# %%
df=df.set_index("country",drop=False)

# %%
df
# Out:
#                       rank           city               country  \
# country
# Hong Kong                1      Hong Kong             Hong Kong
# Thailand                 2        Bangkok              Thailand
# England                  3         London               England
# Singapore                4      Singapore             Singapore
# Macau                    5          Macau                 Macau
# France                   6          Paris                France
# United Arab Emirates     7          Dubai  United Arab Emirates
# USA                      8  New York City                   USA
# Malaysia                 9   Kuala Lumpur              Malaysia
# China                   10       Shenzhen                 China
# Thailand                11         Phuket              Thailand
# Turkey                  12       Istanbul                Turkey
# India                   13          Delhi                 India
# ...

# %%
df.loc['Taiwan']
# Out:
# rank                  17
# city              Taipei
# country           Taiwan
# arrivals_2017    9273300
# arrivals_2018    9783300
# Name: Taiwan, dtype: object

# %%
df.loc['Hong Kong']
# Out:
# rank                     1
# city             Hong Kong
# country          Hong Kong
# arrivals_2017     27880300
# arrivals_2018     29827200
# Name: Hong Kong, dtype: object

# %%
df.loc['India','rank']
# Out:
# country
# India    13
# India    19
# Name: rank, dtype: int64

# %%
df.loc['India','city']
# Out:
# country
# India     Delhi
# India    Mumbai
# Name: city, dtype: object

# %%
df.loc['Hong Kong':'Singapore','rank':'city']
# Out:
#            rank       city
# country
# Hong Kong     1  Hong Kong
# Thailand      2    Bangkok
# England       3     London
# Singapore     4  Singapore

# %%
# !pip install fastavro
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 17.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import fastavro
with open('employees.avro','rb') as f:
  reader = fastavro.reader(f)
  records = [r for r in reader]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3197364057.py in <cell line: 0>()
#       1 import pandas as pd
#       2 import fastavro
# ----> 3 with open('employees.avro','rb') as f:
#       4   reader = fastavro.reader(f)
#       5   records = [r for r in reader]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'employees.avro'
